# %% [markdown]
# ## 1. Load Required Libraries

# %%
# import packages
import pandas as pd
import numpy as np
import src.util as utils
import joblib
import yaml
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler, SMOTE

# %% [markdown]
# ## 2. Import Configuration and Load Dataset

# %%
config = utils.load_config()

# %%
def load_dataset(config: dict):
        # Load every set of data
    X_train = utils.pickle_load(config["train_set_path"][0])
    y_train = utils.pickle_load(config["train_set_path"][1])

    X_valid = utils.pickle_load(config["valid_set_path"][0])
    y_valid = utils.pickle_load(config["valid_set_path"][1])

    X_test = utils.pickle_load(config["test_set_path"][0])
    y_test = utils.pickle_load(config["test_set_path"][1])

    # Concatenate x and y each set
    train_set = pd.concat([X_train, y_train], axis = 1)
    valid_set = pd.concat([X_valid, y_valid], axis = 1)
    test_set = pd.concat([X_test, y_test], axis = 1)

    # Return 3 set of data
    return train_set, valid_set, test_set

# %%
train_set, valid_set, test_set = load_dataset(config)

# %% [markdown]
# ## 3. Check or Handling Missing Values

# %%
train_set.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
valid_set.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
test_set.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# ## 4. Balancing Label

# %%
train_set.Outcome.value_counts()
# Out:
# 0    350
# 1    187
# Name: Outcome, dtype: int64

# %% [markdown]
# ### 4.1 Undersampling

# %%
def rus_fit_resample(set_data: pd.DataFrame) -> pd.DataFrame:
    # Create copy of set data
    set_data = set_data.copy()

    # Create sampling object
    rus = RandomUnderSampler(random_state = 123)

    # Balancing set data
    X_rus, y_rus = rus.fit_resample(set_data.drop(columns = config["label"]),
                                 set_data[config["label"]])

    # Concatenate balanced data
    set_data_rus = pd.concat([X_rus, y_rus], axis = 1)

    # Return balanced data
    return set_data_rus

# %%
train_set_rus = rus_fit_resample(train_set)

# %%
train_set_rus
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              2      100             70             52       57  40.5
# 1              5      136             82              0        0   0.0
# 2              2       85             65              0        0  39.6
# 3              8      126             88             36      108  38.5
# 4              1      109             38             18      120  23.1
# ..           ...      ...            ...            ...      ...   ...
# 369            4      146             78              0        0  38.5
# 370            0      107             62             30       74  36.6
# 371            3       80             82             31       70  34.2
# 372           10      161             68             23      132  25.5
# 373            0      140             65             26      130  42.6
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.677   25        0
# 1                       0.640   69        0
# 2                       0.930   27        0
# 3                       0.349   49        0
# 4                       0.407   26        0
# ..                        ...  ...      ...
# 369                     0.520   67        1
# 370                     0.757   25        1
# 371                     1.292   27        1
# 372                     0.326   47        1
# 373                     0.431   24        1
#
# [374 rows x 9 columns]

# %% [markdown]
# ### 4.2 Oversampling

# %%
def ros_fit_resample(set_data: pd.DataFrame) -> pd.DataFrame:
    # Create copy of set data
    set_data = set_data.copy()

    # Create sampling object
    ros = RandomOverSampler(random_state = 123)

    # Balancing set data
    X_ros, y_ros = ros.fit_resample(set_data.drop(columns = config["label"]),
                                 set_data[config["label"]])

    # Concatenate balanced data
    set_data_ros = pd.concat([X_ros, y_ros], axis = 1)

    # Return balanced data
    return set_data_ros

# %%
train_set_ros = ros_fit_resample(train_set)

# %%
train_set_ros
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             13      152             90             33       29  26.8
# 1              0      104             64             37       64  33.6
# 2              5      137            108              0        0  48.8
# 3              0      111             65              0        0  24.6
# 4              6      105             70             32       68  30.8
# ..           ...      ...            ...            ...      ...   ...
# 695            7      161             86              0        0  30.4
# 696            3      173             78             39      185  33.8
# 697            5      139             80             35      160  31.6
# 698            0      146             70              0        0  37.9
# 699            6      125             78             31        0  27.6
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.731   43        1
# 1                       0.510   22        1
# 2                       0.227   37        1
# 3                       0.660   31        0
# 4                       0.122   37        0
# ..                        ...  ...      ...
# 695                     0.165   47        1
# 696                     0.970   31        1
# 697                     0.361   25        1
# 698                     0.334   28        1
# 699                     0.565   49        1
#
# [700 rows x 9 columns]

# %% [markdown]
# ### 4.3 SMOTE

# %%
def sm_fit_resample(set_data: pd.DataFrame) -> pd.DataFrame:
    # Create copy of set data
    set_data = set_data.copy()

    # Create sampling object
    sm = SMOTE(random_state = 123)

    # Balancing set data
    X_sm, y_sm = sm.fit_resample(set_data.drop(columns = config["label"]),
                                 set_data[config["label"]])

    # Concatenate balanced data
    set_data_sm = pd.concat([X_sm, y_sm], axis = 1)

    # Return balanced data
    return set_data_sm

# %%
train_set_sm = sm_fit_resample(train_set)

# %%
train_set_sm
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 0             13      152             90             33       29  26.800000
# 1              0      104             64             37       64  33.600000
# 2              5      137            108              0        0  48.800000
# 3              0      111             65              0        0  24.600000
# 4              6      105             70             32       68  30.800000
# ..           ...      ...            ...            ...      ...        ...
# 695            7      161             85              0        0  30.639206
# 696            0      184             98             25        0  38.253784
# 697            5      126             71              0        0  27.922621
# 698            0      127             55             31      166  37.781807
# 699            6      187             54             33      371  33.076193
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                    0.731000   43        1
# 1                    0.510000   22        1
# 2                    0.227000   37        1
# 3                    0.660000   31        0
# 4                    0.122000   37        0
# ..                        ...  ...      ...
# 695                  0.163306   46        1
# 696                  0.536265   33        1
# 697                  0.411182   27        1
# 698                  1.027951   33        1
# 699                  0.751857   32        1
#
# [700 rows x 9 columns]

# %%
train_set_sm.Outcome.value_counts()
# Out:
# 1    350
# 0    350
# Name: Outcome, dtype: int64

# %% [markdown]
# ## 5. Handling Outliers

# %%
def remove_outliers(set_data):
    set_data = set_data.copy()
    list_of_set_data = list()

    for col_name in set_data.columns[:-1]:
        q1 = set_data[col_name].quantile(0.25)
        q3 = set_data[col_name].quantile(0.75)
        iqr = q3 - q1
        set_data_cleaned = set_data[~((set_data[col_name] < (q1 - 1.5 * iqr)) | (set_data[col_name] > (q3 + 1.5 * iqr)))].copy()
        list_of_set_data.append(set_data_cleaned.copy())
    
    set_data_cleaned = pd.concat(list_of_set_data)
    count_duplicated_index = set_data_cleaned.index.value_counts()
    used_index_data = count_duplicated_index[count_duplicated_index == (set_data.shape[1]-1)].index
    set_data_cleaned = set_data_cleaned.loc[used_index_data].drop_duplicates()

    return set_data_cleaned

# %%
# remove outlier set rus
train_set_rus_bal_cleaned = remove_outliers(train_set_rus)

# %%
train_set_rus_bal_cleaned
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              2      100             70             52       57  40.5
# 243            8      197             74              0        0  25.9
# 240            6      147             80              0        0  29.5
# 239            4      148             60             27      318  30.9
# 238            9      145             80             46      130  37.9
# ..           ...      ...            ...            ...      ...   ...
# 154            1       86             66             52       65  41.3
# 111            6      144             72             27      228  33.9
# 110            2      127             46             21      335  34.4
# 109            1       89             76             34       37  31.2
# 103            5       44             62              0        0  25.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.677   25        0
# 243                     1.191   39        1
# 240                     0.178   50        1
# 239                     0.150   29        1
# 238                     0.637   40        1
# ..                        ...  ...      ...
# 154                     0.917   29        0
# 111                     0.255   40        0
# 110                     0.176   22        0
# 109                     0.192   23        0
# 103                     0.587   36        0
#
# [310 rows x 9 columns]

# %%
# remove outlier set ros
train_set_ros_bal_cleaned = remove_outliers(train_set_ros)

# %%
train_set_ros_bal_cleaned
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             13      152             90             33       29  26.8
# 440            2       98             60             17      120  34.7
# 431            3      112             74             30        0  31.6
# 432            7      129             68             49      125  38.5
# 433            4      128             70              0        0  34.3
# ..           ...      ...            ...            ...      ...   ...
# 234            9       57             80             37        0  32.8
# 233            1      109             60              8      182  25.4
# 230            7       62             78              0        0  32.6
# 231            7      133             84              0        0  40.2
# 232            1       83             68              0        0  18.2
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.731   43        1
# 440                     0.198   22        0
# 431                     0.197   25        1
# 432                     0.439   43        1
# 433                     0.303   24        0
# ..                        ...  ...      ...
# 234                     0.096   41        0
# 233                     0.947   21        0
# 230                     0.391   41        0
# 231                     0.696   37        0
# 232                     0.624   27        0
#
# [454 rows x 9 columns]

# %%
# remove outlier set sm
train_set_sm_bal_cleaned = remove_outliers(train_set_sm)

# %%
train_set_sm_bal_cleaned
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             13      152             90             33       29  26.8
# 456            4      154             62             31      284  32.8
# 444            2       99             70             16       44  20.4
# 445            7      161             86              0        0  30.4
# 446            2      108             64              0        0  30.8
# ..           ...      ...            ...            ...      ...   ...
# 213            6      104             74             18      156  29.9
# 212            3      162             52             38        0  37.2
# 308            1      115             70             30       96  34.6
# 275            1      100             66             15       56  23.6
# 211            9       72             78             25        0  31.6
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.731   43        1
# 456                     0.237   23        0
# 444                     0.235   27        0
# 445                     0.165   47        1
# 446                     0.158   21        0
# ..                        ...  ...      ...
# 213                     0.722   41        1
# 212                     0.652   24        1
# 308                     0.529   32        1
# 275                     0.666   26        0
# 211                     0.280   38        0
#
# [585 rows x 9 columns]

# %% [markdown]
# ## 6. Dump Dataset

# %%
x_train = {
    "Undersampling" : train_set_rus_bal_cleaned.drop(columns = "Outcome"),
    "Oversampling" : train_set_ros_bal_cleaned.drop(columns = "Outcome"),
    "SMOTE" : train_set_sm_bal_cleaned.drop(columns = "Outcome")
}

y_train = {
    "Undersampling" : train_set_rus_bal_cleaned.Outcome,
    "Oversampling" : train_set_ros_bal_cleaned.Outcome,
    "SMOTE" : train_set_sm_bal_cleaned.Outcome
}

# %%
utils.pickle_dump(x_train, "data/processed/X_train_feng.pkl")
utils.pickle_dump(y_train, "data/processed/y_train_feng.pkl")

utils.pickle_dump(valid_set.drop(columns = "Outcome"), "data/processed/X_valid_feng.pkl")
utils.pickle_dump(valid_set.Outcome, "data/processed/y_valid_feng.pkl")

utils.pickle_dump(test_set.drop(columns = "Outcome"), "data/processed/X_test_feng.pkl")
utils.pickle_dump(test_set.Outcome, "data/processed/y_test_feng.pkl")
